# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


#statistic
from scipy import stats

from mylibrary.get_data import ambilcsv

import warnings 
warnings.filterwarnings("ignore")

# %%
from mylibrary.get_data import ambilcsv

# %%
df = ambilcsv().copy()

# %%
df_stats = df.describe().transpose()
df_stats
# Out:
#                  count           mean            std      min        25%  \
# price          21613.0  540088.141767  367127.196483  75000.0  321950.00
# bedrooms       21613.0       3.370842       0.930062      0.0       3.00
# bathrooms      21613.0       2.114757       0.770163      0.0       1.75
# sqft_living    21613.0    2079.899736     918.440897    290.0    1427.00
# sqft_lot       21613.0   15106.967566   41420.511515    520.0    5040.00
# floors         21613.0       1.494309       0.539989      1.0       1.00
# waterfront     21613.0       0.007542       0.086517      0.0       0.00
# view           21613.0       0.234303       0.766318      0.0       0.00
# condition      21613.0       3.409430       0.650743      1.0       3.00
# grade          21613.0       7.656873       1.175459      1.0       7.00
# sqft_above     21613.0    1788.390691     828.090978    290.0    1190.00
# sqft_basement  21613.0     291.509045     442.575043      0.0       0.00
# ...

# %%
iqr = df_stats['75%'] - df_stats['25%']
batas_bawah = df_stats['25%'] - (1.5*iqr)
batas_atas = df_stats['75%'] + (1.5*iqr)

outlier = [i for i in df['price'] if i < batas_bawah['price'].item() or i > batas_atas['price'].item()]

print('Count of Outliers in Column Price :', len(outlier), 'Data')
# Out:
# Count of Outliers in Column Price : 1146 Data

# %%
iqr = df_stats['75%'] - df_stats['25%']
batas_bawah = df_stats['25%'] - (1.5*iqr)
batas_atas = df_stats['75%'] + (1.5*iqr)

outlier = [i for i in df['bedrooms'] if i < batas_bawah['bedrooms'].item() or i > batas_atas['bedrooms'].item()]

print('Count of Outliers in Column bedrooms :', len(outlier), 'Data')
# Out:
# Count of Outliers in Column bedrooms : 546 Data

# %%
iqr = df_stats['75%'] - df_stats['25%']
batas_bawah = df_stats['25%'] - (1.5*iqr)
batas_atas = df_stats['75%'] + (1.5*iqr)

outlier = [i for i in df['bathrooms'] if i < batas_bawah['bathrooms'].item() or i > batas_atas['bathrooms'].item()]

print('Count of Outliers in Column bathrooms :', len(outlier), 'Data')
# Out:
# Count of Outliers in Column bathrooms : 571 Data

# %%
iqr = df_stats['75%'] - df_stats['25%']
batas_bawah = df_stats['25%'] - (1.5*iqr)
batas_atas = df_stats['75%'] + (1.5*iqr)

outlier_landsize = [i for i in df['sqft_living'] if i < batas_bawah['sqft_living'].item() or i > batas_atas['sqft_living'].item()]

print('Count of Outliers in Column sqft_living :', len(outlier_landsize), 'Data')
# Out:
# Count of Outliers in Column sqft_living : 572 Data

# %%
iqr = df_stats['75%'] - df_stats['25%']
batas_bawah = df_stats['25%'] - (1.5*iqr)
batas_atas = df_stats['75%'] + (1.5*iqr)

outlier_landsize = [i for i in df['sqft_lot'] if i < batas_bawah['sqft_lot'].item() or i > batas_atas['sqft_lot'].item()]

print('Count of Outliers in Column sqft_lot :', len(outlier_landsize), 'Data')
# Out:
# Count of Outliers in Column sqft_lot : 2425 Data

# %%
iqr = df_stats['75%'] - df_stats['25%']
batas_bawah = df_stats['25%'] - (1.5*iqr)
batas_atas = df_stats['75%'] + (1.5*iqr)

outlier_landsize = [i for i in df['sqft_above'] if i < batas_bawah['sqft_above'].item() or i > batas_atas['sqft_above'].item()]

print('Count of Outliers in Column sqft_above :', len(outlier_landsize), 'Data')
# Out:
# Count of Outliers in Column sqft_above : 611 Data

# %%
iqr = df_stats['75%'] - df_stats['25%']
batas_bawah = df_stats['25%'] - (1.5*iqr)
batas_atas = df_stats['75%'] + (1.5*iqr)

outlier_landsize = [i for i in df['sqft_basement'] if i < batas_bawah['sqft_basement'].item() or i > batas_atas['sqft_basement'].item()]

print('Count of Outliers in Column sqft_basement :', len(outlier_landsize), 'Data')
# Out:
# Count of Outliers in Column sqft_basement : 496 Data

# %%
for columns in df[['price','bedrooms','bathrooms','sqft_living','sqft_lot','sqft_above','sqft_basement']]:

    plt.figure(figsize=(12,10))
    ax = sns.boxplot(x = columns,data=df, color = 'y');

# %%
df1 = df[['price','bedrooms','bathrooms','sqft_living','sqft_lot','sqft_above','sqft_basement']]

# %%
for i, col in enumerate(df1.columns):
    plt.figure(figsize=(12,10))
    plt.figure(i)
    sns.distplot(df1[col]);

# %%
k2, p = stats.normaltest(df['price'])
alpha = 1e-3
print("p = {:g}".format(p))

if p < alpha:  # null hypothesis: x comes from a normal distribution
    print("The null hypothesis can be rejected")
else:
    print("The null hypothesis cannot be rejected")
# Out:
# p = 0
# The null hypothesis can be rejected
